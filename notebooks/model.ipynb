# %%
import sys
sys.path.append('../')

from models.covidprocess import DataCovid
from models.linear import NaiveLinearModel
from models.compart import SIR

# %% [markdown]
# ## Train linear model

# %%
data = DataCovid().read()
linear_model = NaiveLinearModel(data)
linear_model.plot(start_fit=60)
# Out:
# Reading data...
# Reading complited!
# Not predicted yet.
# Wait for prediction ...
# Not fitted yet.
# Wait for fitting ...
# Train msle = 0.01188
# Train msle = 0.07369
# Fitted successfully
# Predicted succesfully

# %% [markdown]
# # Train compartmental model

# %%
model = SIR(data)
model.plot()
# Out:
# Not fitted yet.
# Start fitting. Wait ...
# Successfully.
